# %% [markdown]
# <a href="https://colab.research.google.com/github/w3aarush/python-ml-learning/blob/main/python/Error_Handling_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Single Error Handling

# %%
try:
    x = 2
    y = x * "5"

    if y <= 25:
        print("The number is less than or equal to 25")
except Exception as e:
    print(f"Character can't be multiplied./nThe error is {e}")
# Out:
# Character can't be multiplied./nThe error is '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### Real Time Error Handling

# %%
class InvalidSalary(Exception):
    pass

# %%
class Employee:
    def __init__(self, first, age, salary):
        self.first = first
        self.age = age

        if salary < 0:
            raise InvalidSalary("Salary can't be negative.")
        self.salary = salary

    def display(self):
        print(self.first)
        print(self.age)
        print(self.salary)

try:
    details = {
        'name': 'ram',
        'age': 21,
        'salary': -1000
    }

    emp = Employee(details['name'],details['age'], details['salary'])
    emp.display()
except InvalidSalary as e:
    print(e)
# Out:
# Salary can't be negative.

# %% [markdown]
# ### Multiple Error Handling

# %%
try:
    x = int(input("Enter a number"))
    y = int(input("Enter your second number:"))
    res = x / y
except Exception as e:
    print("Error : ", e)

except ZeroDivisionError as e:
    print("Error : ", e)

except TypeError as e:
    print("Error : ", e)

except ValueError as e:
    print("Error : ", e)

else:
    print(res)
finally:
    print("I am done for today.")
# Out:
# Enter a number35
# Enter your second number:5
# 7.0
# I am done for today.
