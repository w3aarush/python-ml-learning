# %% [markdown]
# <a href="https://colab.research.google.com/github/w3aarush/python-ml-learning/blob/main/dsa/Day_2_Learning_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list - mutable,ordered,allows duplicates,hetrogeneous
lst=[1,2,3,"ram"]
#print elements
print(lst[3])
print(type(lst[3]))
print(type(lst[1]))
# concatination
lst.append(5)
print(lst)
total=0
# for loop for adding two numbers
for i in lst:
    if type(i)==int:
      total = total+i
print(total)

lst.append(2)
# remove
print(lst)
print(lst.remove(5))
print(lst)
# list slicing
print(lst[0:2])
# Out:
# ram
# <class 'str'>
# <class 'int'>
# [1, 2, 3, 'ram', 5]
# 11
# [1, 2, 3, 'ram', 5, 2]
# None
# [1, 2, 3, 'ram', 2]
# [1, 2]

# %%
# sets - mutable,unordered,unique elements/does not allow duplicates,hetrogenous
s = {1,2,3,'cam'}
print(s)
type(s)
#key-value pairs
s1={'name':'riku',
    'age':21}
print(s1)
print(s1['name'])

#remove function
s.remove(1)
print(s)
#add function - concat
s.add(4)
print(s)
#we cant add duplicates
s.add(4)
print(s)
# Out:
# {1, 2, 3, 'cam'}
# {'name': 'riku', 'age': 21}
# riku
# {2, 3, 'cam'}
# {2, 3, 4, 'cam'}
# {2, 3, 4, 'cam'}

# %%
# Tuples
tuple_demo = (2, 'a', True)
for element in tuple_demo:
  print(type(element))

tuple_demowithoutBoolean = ()
for element in tuple_demo:
  if type(element) is not bool:
    tuple_demowithoutBoolean += (element,)

print(tuple_demowithoutBoolean)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# (2, 'a')

# %% [markdown]
# <h5>Tuples Work</h5>

# %% [markdown]
# **Homework  for 20th Feb**
#
# Create a tuple with 6 colors.
#
# Print:
#
# The first 3 elements
#
# The last 2 elements

# %%
tuple_SixColors = 'red', 'green', 'blue', 'black', 'white'

# first 3 element
print(tuple_SixColors[:3])
# last 3 element
print(tuple_SixColors[-2:])
# Out:
# ('red', 'green', 'blue')
# ('black', 'white')
