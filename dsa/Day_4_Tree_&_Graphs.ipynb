# %% [markdown]
# <a href="https://colab.research.google.com/github/w3aarush/python-ml-learning/blob/main/dsa/Day_4_Tree_%26_Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In a tree we have roots, branches, with leaves
# Tree is way to store data in hierarichal structure
# every nodes can have child nodes
# every node will have only one parent

# %% [markdown]
# One of the very basic type of tree structure is **Binary Tree**.
# * In **binary tree**, each node has maximum **two** children; left child and right child.

# %%
# A binary tree
class binaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        # create nodes
        root = binaryTreeNode(1)
        root.left = binaryTreeNode(2)
        root.right = binaryTreeNode(3)
        root.left.left = binaryTreeNode(4)
        root.left.right = binaryTreeNode(5)
        root.right.left = binaryTreeNode(6)
        root.right.right = binaryTreeNode(7)
        def inorder(binaryTreeNode):
            if binaryTreeNode:
                inorder(binaryTreeNode.left)
                print(binaryTreeNode.data, end=" ")
                inorder(binaryTreeNode.right)
                print("Inorder Traversal:")
                inorder(root)

# %%
# learn about binary search tree

# %%
# create a basic binaryTreeNode
class binaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# %%
root = binaryTreeNode(1)

# %%
root.left = binaryTreeNode(2)
root.right = binaryTreeNode(3)
root.left.left = binaryTreeNode(4)
root.left.right = binaryTreeNode(5)
root.right.left = binaryTreeNode(6)
root.right.right = binaryTreeNode(7)

# %%
# Inorder traversal visits the node in the order: Left -> Root -> Right
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=" ")
        inorder(node.right)

print("Inorder Traversal:")
inorder(root)
# Out:
# Inorder Traversal:
# 4 2 5 1 6 3 7

# %%
# Preorder traversal visits the node in the order: Root -> Left -> Right
def preorder(node):
    if node:
        print(node.data, end=" ")
        preorder(node.left)
        preorder(node.right)

# %%
preorder(root)
# Out:
# 1 2 4 5 3 6 7

# %%
# Postorder traversal visits the node in the order: Left -> Right -> Root
def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=" ")

# %%
postorder(root)
# Out:
# 4 5 2 6 7 3 1

# %% [markdown]
# <h3>Binary Search Tree</h3>
# <p>A type of binary tree in which nodes left of the root contains less value than the root node and the nodes right of the root node contains greater values than the root node.</p>
