# %% [markdown]
# <a href="https://colab.research.google.com/github/w3aarush/python-ml-learning/blob/main/dsa/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {'name':'riku', 'age':21}

# %%
type(s1)
# Out:
# dict

# %%
s2 = {'Student':{'name':'riku','age':21}, 'Address': {'Street': '11', 'Postal Code': '40000'}}

# %%
type(s2)
# Out:
# dict

# %%
s2 = set()

# %%
type(s2)
# Out:
# set

# %%
s2 = {2,4,5,8}

# %%
type(s2)
# Out:
# set

# %%
s2 = {'aarush',2345, 6.6}

# %%
type(s2)
# Out:
# set

# %%
s2 = {'name':'riku', 'age':21,'street':'11'}

# %%
type(s2)
# Out:
# dict

# %%
s2 = set('name':'riku','class':5)
# Out:
#   File "/tmp/ipython-input-1612419187.py", line 1
#     s2 = set('name':'riku','class':5)
#                    ^
# SyntaxError: invalid syntax

# %%
s2 = set({'name':'rahul','class':5})

# %%
type(s2)
# Out:
# set
